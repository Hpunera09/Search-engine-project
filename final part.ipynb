# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df=pd.read_csv("clean_data.csv")

# %%
df.drop(columns=["Unnamed: 0"], inplace=True)

# %%
df.head()
# Out:
#    subtitle_id                                               name  \
# 0      9251120                     maybe.this.time.(2014).eng.1cd
# 1      9211589  down.the.shore.s01.e10.and.justice.for.all.(19...
# 2      9380845  uncontrollably.fond.s01.e07.heartache.(2016).e...
# 3      9301436  screen.two.s13.e04.the.precious.blood.(1996).e...
# 4      9408707                          battlebots.(2015).eng.1cd
#
#                                           clean_data
# 0  watch any video online with open subtitle free...
# 1  oh i know that it s getting late but i don t w...
# 2  i timing and subtitle by the uncontrollable lo...
# 3  ethereal music api opensubtitles org is deprec...
# 4  chris oh no not the minibots yelling oh you le...

# %%
from tqdm import tqdm, tqdm_notebook
tqdm.pandas()
def chunk_text(text, chunk_size=500, overlap_size=50):
    chunks = []
    words = text.split()
    start_idx = 0
    while start_idx < len(words):
        end_idx = min(start_idx + chunk_size, len(words))
        chunk = ' '.join(words[start_idx:end_idx])
        chunks.append(chunk)
        start_idx += chunk_size - overlap_size
    return chunks

# Apply chunking function to the 'clean_subtitles' column
chunk_size = 500  # Number of tokens per chunk
overlap_size = 50  # Number of tokens to overlap between chunks

df['chunks'] = df['clean_data'].progress_apply(lambda x: chunk_text(x, chunk_size, overlap_size))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 24749/24749 [00:17<00:00, 1393.57it/s]

# %%
df.shape
# Out:
# (24749, 4)

# %%
df_exploded = df.explode('chunks')

# %%
df_exploded.head()
# Out:
#    subtitle_id                            name  \
# 0      9251120  maybe.this.time.(2014).eng.1cd
# 0      9251120  maybe.this.time.(2014).eng.1cd
# 0      9251120  maybe.this.time.(2014).eng.1cd
# 0      9251120  maybe.this.time.(2014).eng.1cd
# 0      9251120  maybe.this.time.(2014).eng.1cd
#
#                                           clean_data  \
# 0  watch any video online with open subtitle free...
# 0  watch any video online with open subtitle free...
# 0  watch any video online with open subtitle free...
# 0  watch any video online with open subtitle free...
# 0  watch any video online with open subtitle free...
#
#                                               chunks
# 0  watch any video online with open subtitle free...
# 0  a point oh tonio seventy snack seven seven sil...
# 0  like it yes you know this is my favorite spot ...
# 0  i wa suddenly given you surprised me a vacatio...
# 0  presentation in fairness that s so good your p...

# %%
df_exploded.shape
# Out:
# (311548, 4)

# %%
pip install -U sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\harsh\anaconda3\lib\site-packages (2.7.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in c:\users\harsh\anaconda3\lib\site-packages (from sentence-transformers) (4.39.3)
# Requirement already satisfied: tqdm in c:\users\harsh\anaconda3\lib\site-packages (from sentence-transformers) (4.65.0)
# Requirement already satisfied: torch>=1.11.0 in c:\users\harsh\anaconda3\lib\site-packages (from sentence-transformers) (2.2.2)
# Requirement already satisfied: numpy in c:\users\harsh\anaconda3\lib\site-packages (from sentence-transformers) (1.26.4)
# Requirement already satisfied: scikit-learn in c:\users\harsh\anaconda3\lib\site-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in c:\users\harsh\anaconda3\lib\site-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.15.1 in c:\users\harsh\anaconda3\lib\site-packages (from sentence-transformers) (0.22.2)
# Requirement already satisfied: Pillow in c:\users\harsh\anaconda3\lib\site-packages (from sentence-transformers) (10.2.0)
# Requirement already satisfied: filelock in c:\users\harsh\anaconda3\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\harsh\anaconda3\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2023.10.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\harsh\anaconda3\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\harsh\anaconda3\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in c:\users\harsh\anaconda3\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\harsh\anaconda3\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.9.0)
# Requirement already satisfied: sympy in c:\users\harsh\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in c:\users\harsh\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in c:\users\harsh\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.3)
# Requirement already satisfied: colorama in c:\users\harsh\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\harsh\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2023.10.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\harsh\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\harsh\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.4.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\harsh\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\harsh\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\harsh\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\harsh\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\harsh\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\harsh\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\harsh\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\harsh\anaconda3\lib\site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)

# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
from tqdm import tqdm
tqdm.pandas()

def encode_and_convert_to_list(text):
    encoded_vector = model.encode(text).tolist()
    return encoded_vector

# Apply the function to each element of 'chunks'
df_exploded['doc_vector_pretrained_bert'] = df_exploded['chunks'].progress_apply(encode_and_convert_to_list)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 311548/311548 [16:23:31<00:00,  5.28it/s]

# %%
df_bert_pretrained = list(df_exploded.doc_vector_pretrained_bert)

# %%
# Initialize empty lists
documents = []
metadatas = []
ids = []
id = 1

# Iterate over DataFrame rows
for index, row in df_exploded.iterrows():
    # Append document from DataFrame to documents list
    documents.append(row['chunks'])

    # Append metadata (subtitle_id) from DataFrame to metadatas list
    metadatas.append({"subtitle_id": row['subtitle_id'], "name": row['name']})

    # Append unique ID to ids list
    ids.append(str(id))

    # Increment ID
    id += 1

# %%
pip install chromadb
# Out:
# Requirement already satisfied: chromadb in c:\users\harsh\anaconda3\lib\site-packages (0.4.24)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: build>=1.0.3 in c:\users\harsh\anaconda3\lib\site-packages (from chromadb) (1.2.1)
# Requirement already satisfied: requests>=2.28 in c:\users\harsh\anaconda3\lib\site-packages (from chromadb) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in c:\users\harsh\anaconda3\lib\site-packages (from chromadb) (1.10.12)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in c:\users\harsh\anaconda3\lib\site-packages (from chromadb) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\harsh\anaconda3\lib\site-packages (from chromadb) (0.110.1)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\harsh\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.29.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\harsh\anaconda3\lib\site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\harsh\anaconda3\lib\site-packages (from chromadb) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\harsh\anaconda3\lib\site-packages (from chromadb) (4.9.0)
# Requirement already satisfied: pulsar-client>=3.1.0 in c:\users\harsh\anaconda3\lib\site-packages (from chromadb) (3.5.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\harsh\anaconda3\lib\site-packages (from chromadb) (1.17.3)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\harsh\anaconda3\lib\site-packages (from chromadb) (1.24.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\harsh\anaconda3\lib\site-packages (from chromadb) (1.24.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\harsh\anaconda3\lib\site-packages (from chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\harsh\anaconda3\lib\site-packages (from chromadb) (1.24.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\harsh\anaconda3\lib\site-packages (from chromadb) (0.15.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\harsh\anaconda3\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\harsh\anaconda3\lib\site-packages (from chromadb) (4.65.0)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\harsh\anaconda3\lib\site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\harsh\anaconda3\lib\site-packages (from chromadb) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\harsh\anaconda3\lib\site-packages (from chromadb) (1.62.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\harsh\anaconda3\lib\site-packages (from chromadb) (4.1.2)
# Requirement already satisfied: typer>=0.9.0 in c:\users\harsh\anaconda3\lib\site-packages (from chromadb) (0.12.3)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\harsh\anaconda3\lib\site-packages (from chromadb) (29.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\harsh\anaconda3\lib\site-packages (from chromadb) (8.2.3)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\harsh\anaconda3\lib\site-packages (from chromadb) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\harsh\anaconda3\lib\site-packages (from chromadb) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\harsh\anaconda3\lib\site-packages (from chromadb) (3.10.1)
# Requirement already satisfied: packaging>=19.1 in c:\users\harsh\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (23.1)
# Requirement already satisfied: pyproject_hooks in c:\users\harsh\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (1.0.0)
# Requirement already satisfied: colorama in c:\users\harsh\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\harsh\anaconda3\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.37.2)
# Requirement already satisfied: certifi>=14.05.14 in c:\users\harsh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2024.2.2)
# Requirement already satisfied: six>=1.9.0 in c:\users\harsh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\harsh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\harsh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.29.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\harsh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.58.0)
# Requirement already satisfied: requests-oauthlib in c:\users\harsh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\harsh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\harsh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.7)
# Requirement already satisfied: coloredlogs in c:\users\harsh\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\harsh\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in c:\users\harsh\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (3.20.3)
# Requirement already satisfied: sympy in c:\users\harsh\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\harsh\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<=7.0,>=6.0 in c:\users\harsh\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.0.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\harsh\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.63.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.24.0 in c:\users\harsh\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.24.0)
# Requirement already satisfied: opentelemetry-proto==1.24.0 in c:\users\harsh\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.24.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.45b0 in c:\users\harsh\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.45b0 in c:\users\harsh\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.45b0 in c:\users\harsh\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-util-http==0.45b0 in c:\users\harsh\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: setuptools>=16.0 in c:\users\harsh\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (68.2.2)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\harsh\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in c:\users\harsh\anaconda3\lib\site-packages (from opentelemetry-instrumentation-asgi==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\harsh\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\harsh\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\harsh\anaconda3\lib\site-packages (from requests>=2.28->chromadb) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\harsh\anaconda3\lib\site-packages (from requests>=2.28->chromadb) (3.4)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in c:\users\harsh\anaconda3\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.22.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\harsh\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\harsh\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\harsh\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (13.3.5)
# Requirement already satisfied: h11>=0.8 in c:\users\harsh\anaconda3\lib\site-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\harsh\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\harsh\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\harsh\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\harsh\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (12.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\harsh\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\harsh\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\harsh\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in c:\users\harsh\anaconda3\lib\site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\harsh\anaconda3\lib\site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2023.10.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\harsh\anaconda3\lib\site-packages (from importlib-metadata<=7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\harsh\anaconda3\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\harsh\anaconda3\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (2.15.1)
# Requirement already satisfied: anyio<5,>=3.4.0 in c:\users\harsh\anaconda3\lib\site-packages (from starlette<0.38.0,>=0.37.2->fastapi>=0.95.2->chromadb) (4.2.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\harsh\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\harsh\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\harsh\anaconda3\lib\site-packages (from anyio<5,>=3.4.0->starlette<0.38.0,>=0.37.2->fastapi>=0.95.2->chromadb) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\harsh\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.4.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\harsh\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb) (0.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\harsh\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)

# %%
import chromadb

# %%
client = chromadb.PersistentClient(path="vectordb")

# %%
client.heartbeat()
# Out:
# 1713843177545200400

# %%
collection = client.create_collection(
        name="Data",
        metadata={"hnsw:space": "cosine"}
    )

# %%
from tqdm import tqdm

batch_size = 5000
total_batches = (len(documents) + batch_size - 1) // batch_size

for i in tqdm(range(total_batches), desc="Adding batches"):
    start_idx = i * batch_size
    end_idx = min((i + 1) * batch_size, len(documents))

    batch_doc = documents[start_idx:end_idx]
    batch_metadatas = metadatas[start_idx:end_idx]
    batch_ids = ids[start_idx:end_idx]
    embed = df_bert_pretrained[start_idx:end_idx]

    collection.add(
        embeddings=embed,
        documents=batch_doc,
        metadatas=batch_metadatas,
        ids=batch_ids
    )
# Out:
# Adding batches: 100%|██████████████████████████████████████████████████████████████| 63/63 [14:09:20<00:00, 808.90s/it]

# %%
import chromadb
client = chromadb.PersistentClient(path="vectordb")
collection = client.get_collection(name="Data")

# %%
def encode_query(query_point, model):
    """
    Encode the query point using the provided model.
    """
    return model.encode(query_point).tolist()

# %%
def print_movie_info(result):
    """
    Extract movie names and subtitle IDs from the query results.
    """
    movie_info = [(meta['name'], meta['subtitle_id']) for sublist in result['metadatas'] for meta in sublist if 'name' in meta and 'subtitle_id' in meta]
    return movie_info

# %%
prompt="Horror"

# %%
doc_vector = encode_query(prompt, model)

# %%
result = collection.query(
    query_embeddings=doc_vector,
    n_results=10
)

# %%
movie_info = result

# %%
movie_info
# Out:
# {'ids': [['165679',
#    '301121',
#    '116303',
#    '165643',
#    '265161',
#    '301123',
#    '108003',
#    '126093',
#    '165680',
#    '116300']],
#  'distances': [[0.6076998710632324,
#    0.613140881061554,
#    0.6222995519638062,
#    0.6291930079460144,
#    0.6295484304428101,
#    0.6315937638282776,
#    0.6480051279067993,
#    0.6513936519622803,
#    0.6526635885238647,
#    0.6533650159835815]],
#  'metadatas': [[{'name': 'in.search.of.darkness.part.iii.(2022).eng.2cd',
#     'subtitle_id': 9417477},
#    {'name': 'blumhouses.compendium.of.horror.s01.e01.american.monsters.(2022).eng.1cd',
#     'subtitle_id': 9260194},
#    {'name': 'living.with.chucky.(2022).eng.1cd', 'subtitle_id': 9493886},
#    {'name': 'in.search.of.darkness.part.iii.(2022).eng.2cd',
#     'subtitle_id': 9417477},
#    {'name': 'man.to.man.with.dean.learner.s01.e01.garth.marenghi.(2006).eng.1cd',
#     'subtitle_id': 9383265},
#    {'name': 'blumhouses.compendium.of.horror.s01.e01.american.monsters.(2022).eng.1cd',
#     'subtitle_id': 9260194},
#    {'name': 'unknown.dimension.the.story.of.paranormal.activity.(2021).eng.1cd',
#     'subtitle_id': 9295030},
#    {'name': 'one.of.us.is.lying.s02.e01.simon.says.game.on.(2022).eng.1cd',
#     'subtitle_id': 9281598},
#    {'name': 'in.search.of.darkness.part.iii.(2022).eng.2cd',
#     'subtitle_id': 9417477},
#    {'name': 'living.with.chucky.(2022).eng.1cd', 'subtitle_id': 9493886}]],
#  'embeddings': None,
#  'documents': [['horror explosion when you mention s asian horror a lot of people think of house from japan although that one s from if you watch japanese horror if you watch something from thailand if you watch something from south korea you re going to get a different experience from each of those south korea s horror movement that happened just after j horror explosion ha been incredible south korea indonesia and the philippine kind of came into their own regarding horror a little bit later in term of horror that s commercially viable in the western world in the philippine there s actually a lot of horror it s very sad that i can not count on one hand how many cross over to america one of the best place for asian horror especially out of the s wa china a lot of it wa based on the mythology we see demon vampire ghost poltergeist a lot of witch a lot of wizard a well some movie you should definitely check out are kung fu zombie human lantern seeding of a ghost and witch from nepal with chow yun fat we know the shaw brother and golden harvest a the purveyor of incredible martial art movie but they also dip their toe in a lot of horror a well asian horror cinema i like vampire movie for that scary thing that there is a story of how they got scary the way they present their monster is just so fundamentally different than how the western stereotype of a vampire is just completely blown up in an asian film i m completely obsessed by the mr vampire movie i d never seen jiangshi vampire before i wa mesmerized by how comedic they were they hop when you watch mr vampire you see why people are scared of them because they are relentless and you have to know all of the trick in order to defeat them the jitter is an unusual film plus the jitter wa directed by john fasano and not a chinese guy there s a little bit lost in translation it played fast and loose with chinese mythology quite a lot someone thought that since they re so popular over there we d make an american version of these movie and see how that doe i got him i m uncomfortable with the movie now because there s a lot of racial stereotype in there at the time i didn t really think wa a big deal but it is understanding horror explored through the lens of other culture it s an important thing and it s a cool thing different culture have all these different kind of mythology to draw from and there s just this endless well of story that we can build upon when you re talking about asian horror now people are looking at it from a broader perspective because they ve been able to watch these movie whereas in the s a lot',
#    'campbell it s probably very cathartic why horror work it take you to the edge of life it s one of the few genre that can get an audience to react viscerally that s all horror is these six kid are gonna die one by one maybe one schmo will make it to the end but it s all life and death englund for over a century horror film have been an essential part of american culture they have thrilled u they have entertained u and they have also exorcised our collective demon the horror genre ha always reflected our shared fear and anxiety people they want to be scared i they re coming to get you barbara i scream blum the world is always throwing up new terror that we can turn into horror movie englund i blumhouse s compendium of horror i examines how those film have held a mirror up to society and allowed u to experience and purge our national fear in the shared experience of cinema the scariest fucking thing man we wanted i blair witch i to come from a place of that primal motivation really get under your skin and really scare you englund from the brut